# %% [markdown]
# <a href="https://colab.research.google.com/github/Karan77788/Data_Science/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
data = pd.read_csv('/content/Students_admissions_dataset.csv')
data = data.dropna()
data
# Out:
#       GPA  Extracurriculars  Parental_Income  Hours_Studied  \
# 0    3.28                 0           117196              9
# 1    3.47                 5           117080             18
# 2    2.06                 0            48657              8
# 3    3.12                 5           105181             18
# 4    3.18                 0           119458              6
# ..    ...               ...              ...            ...
# 195  2.76                 4            89541             10
# 196  2.20                 5            34996             18
# 197  3.78                 3            64424             15
# 198  2.63                 2           107177              9
# 199  2.13                 0            32219             14
#
#      Entrance_Test_Score  Distance Internet Final_Result
# 0                     61        15      Yes         Fail
# 1                     41        38       No         Fail
# 2                     94        39      Yes         Fail
# ...

# %%
print(data.head())
# Out:
#     GPA  Extracurriculars  Parental_Income  Hours_Studied  \
# 0  3.28                 0           117196              9
# 1  3.47                 5           117080             18
# 2  2.06                 0            48657              8
# 3  3.12                 5           105181             18
# 4  3.18                 0           119458              6
#
#    Entrance_Test_Score  Distance Internet Final_Result
# 0                   61        15      Yes         Fail
# 1                   41        38       No         Fail
# 2                   94        39      Yes         Fail
# 3                   83        15       No         Fail
# 4                   84        22       No         Fail

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GPA                  200 non-null    float64
#  1   Extracurriculars     200 non-null    int64
#  2   Parental_Income      200 non-null    int64
#  3   Hours_Studied        200 non-null    int64
#  4   Entrance_Test_Score  200 non-null    int64
#  5   Distance             200 non-null    int64
#  6   Internet             200 non-null    object
#  7   Final_Result         200 non-null    object
# dtypes: float64(1), int64(5), object(2)
# memory usage: 12.6+ KB
# None

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

data['Final_Result'] = data['Final_Result'].map({'Fail': 0, 'Pass': 1})
data['Internet'] = data['Internet'].map({'No': 0, 'Yes': 1})

data = data.dropna()

output_dataset = data['Final_Result']
input_dataset = data[['GPA', 'Entrance_Test_Score', 'Internet']]

result_model = LogisticRegression()
result_model.fit(input_dataset, output_dataset)

insert = [[3.5, 55, 0]]
columns = ['GPA', 'Entrance_Test_Score', 'Internet']
column_df = pd.DataFrame(insert, columns=columns)

result_predictions = result_model.predict(column_df)

for i in result_predictions:
    if(i==0):
      print('Fail')
    else:
      print('Pass')
# Out:
# Fail
